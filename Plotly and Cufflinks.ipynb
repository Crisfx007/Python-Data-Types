# %%
import pandas as pd
import numpy as np
from plotly import __version__
import chart_studio.plotly as py
# %matplotlib inline

# %%
print(__version__)
# Out:
# 5.22.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Data
df = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
df.head()
# Out:
#           A         B         C         D
# 0  1.660091  1.510591  0.679890  0.389686
# 1 -1.264772 -0.901914 -1.361221  1.422896
# 2 -0.939079  1.189579  0.156139 -1.038563
# 3 -0.300675  1.151957  0.421387  0.799763
# 4  2.163452 -0.506452 -0.776087 -0.534881

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iplot()

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)

# %%
df2.iplot(kind='bar',x='Category',y='Values')

# %%
df
# Out:
#            A         B         C         D
# 0   1.660091  1.510591  0.679890  0.389686
# 1  -1.264772 -0.901914 -1.361221  1.422896
# 2  -0.939079  1.189579  0.156139 -1.038563
# 3  -0.300675  1.151957  0.421387  0.799763
# 4   2.163452 -0.506452 -0.776087 -0.534881
# ..       ...       ...       ...       ...
# 95 -0.743887 -1.496587  0.293661  0.622139
# 96 -0.379719  0.868803 -0.512919 -0.539220
# 97 -1.887710  0.549783  0.108157 -1.779939
# 98  1.805489  1.578063  0.243751  0.586337
# 99  0.144266  0.321744 -0.610558  0.592995
#
# [100 rows x 4 columns]

# %%
df.iplot(kind='bar') #does not make sense.

# %%
df.count().iplot(kind='bar') #generally used with some kind of aggregate function.

# %%
df.sum().iplot(kind='bar')

# %%
df.iplot(kind='box') #boxplot does the aggregation by itself.

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')

# %%
df['A'].iplot(kind='hist',bins=25)

# %%
df.iplot(kind='hist')

# %%
df[['A','B']].iplot(kind ='spread')
# Out:
# C:\Anaconda\Lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')

# %%
df.scatter_matrix() #kind of like pairgrid.
